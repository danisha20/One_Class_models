# %%
import pandas as pd
import brminer
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Function importing Dataset 
def importdata(trainFile, testFile): 
    train = pd.read_csv(trainFile, sep= ',') 
    test = pd.read_csv(testFile, sep= ',') 
    return train, test    

# Function to split target from data 
def splitdataset(train, test): 
    ohe = OneHotEncoder(sparse=True)
    objInTrain = len(train)

    allData = pd.concat([train, test], ignore_index=True, sort =False, axis=0)
    AllDataWihoutClass = allData.iloc[:, :-1]
    AllDataWihoutClassOnlyNominals = AllDataWihoutClass.select_dtypes(include=['object'])
    AllDataWihoutClassNoNominals = AllDataWihoutClass.select_dtypes(exclude=['object'])

    encAllDataWihoutClassNominals = ohe.fit_transform(AllDataWihoutClassOnlyNominals)
    encAllDataWihoutClassNominalsToPanda = pd.DataFrame(encAllDataWihoutClassNominals.toarray())
    
    if AllDataWihoutClassOnlyNominals.shape[1] > 0:
      codAllDataAgain = pd.concat([encAllDataWihoutClassNominalsToPanda, AllDataWihoutClassNoNominals], ignore_index=True, sort =False, axis=1)
    else:
      codAllDataAgain = AllDataWihoutClass

    # Seperating the target variable 
    X_train = codAllDataAgain[:objInTrain]
    y_train = train.values[:, -1]

    X_test = codAllDataAgain[objInTrain:]
    y_test = test.values[:, -1]
    
    mm_scaler = MinMaxScaler()
    X_train_minmax = pd.DataFrame(mm_scaler.fit_transform(X_train[X_train.columns]), index=X_train.index, columns=X_train.columns)
    X_test_minmax = pd.DataFrame(mm_scaler.transform(X_test[X_test.columns]), index=X_test.index, columns=X_test.columns)
    
    std_scaler = StandardScaler()
    X_train_std = pd.DataFrame(std_scaler.fit_transform(X_train[X_train.columns]), index=X_train.index, columns=X_train.columns)
    X_test_std = pd.DataFrame(std_scaler.transform(X_test[X_test.columns]), index=X_test.index, columns=X_test.columns)
    
    X_train_minmax_std = pd.DataFrame(std_scaler.fit_transform(X_train_minmax[X_train_minmax.columns]), index=X_train_minmax.index, columns=X_train_minmax.columns)
    X_test_minmax_std = pd.DataFrame(std_scaler.transform(X_test_minmax[X_test_minmax.columns]), index=X_test_minmax.index, columns=X_test_minmax.columns)
    
    return X_train, X_test, y_train, y_test, X_train_minmax, X_test_minmax, X_train_std, X_test_std, X_train_minmax_std, X_test_minmax_std

# Function to make predictions 
def prediction(X_test, clf_object):  
    y_pred = clf_object.score_samples(X_test) 
    return y_pred 

def result_of_Class(y_test, y_pred, saveFile):       
    np.savetxt(saveFile, y_pred, fmt='%.4f')

# %%
import os
import time

keel_datasets_path = "Unsupervised_Anomaly_Detection"
keel_datasets_path = os.path.abspath(keel_datasets_path)

for root, dirs, files in os.walk(keel_datasets_path, topdown=False):
    for name in dirs:
        trainFile = keel_datasets_path + "\\" + name + "\\" + name + "-5-1tra.csv"
        testFile = keel_datasets_path + "\\" + name + "\\" + name + "-5-1tst.csv"

        print(name)
        
        tic = time.perf_counter()

        # Loading data 
        train, test = importdata(trainFile, testFile)

        # Training
        X_train, X_test, y_train, y_test, X_train_minmax, X_test_minmax, X_train_std, X_test_std,    X_train_minmax_std, X_test_minmax_std = splitdataset(train, test) 

        clf_classif1 = brminer.BRM()

        clf_classif1.fit(X_train, y_train) 

        y_pred = clf_classif1.score_samples(X_test)
        auc = roc_auc_score(y_test,  y_pred)

        toc = time.perf_counter()

        print(f'Testing AUC: {auc if auc > .5 else 1 - auc}')
        print(f'This took {toc - tic:0.4f} seconds')
# Out:
# abalone-17_vs_7-8-9-10
# Testing AUC: 0.8315058479532164
# This took 6.2208 seconds
# abalone-19_vs_10-11-12-13
# Testing AUC: 0.5956873315363882
# This took 2.9196 seconds
# abalone-20_vs_8-9-10
# Testing AUC: 0.8483245149911817
# This took 3.9546 seconds
# abalone-21_vs_8
# Testing AUC: 0.9883040935672515
# This took 0.5045 seconds
# abalone-3_vs_11
# Testing AUC: 0.6904761904761905
# This took 0.4128 seconds
# abalone19
# Testing AUC: 0.6393244873341375
# This took 18.4293 seconds
# abalone9-18
# Testing AUC: 0.8703703703703703
# This took 0.7210 seconds
# car-good
# Testing AUC: 0.5
# This took 4.0997 seconds
# car-vgood
# Testing AUC: 0.5368445368445368
# This took 4.0960 seconds
# cleveland-0_vs_4
# Testing AUC: 0.9583333333333334
# This took 0.1453 seconds
# dermatology-6
# Testing AUC: 0.6838235294117647
# This took 0.5223 seconds
# ecoli-0-1-3-7_vs_2-6
# Testing AUC: 0.9272727272727272
# This took 0.1565 seconds
# ecoli-0-1-4-6_vs_5
# Testing AUC: 0.7932692307692308
# This took 0.1543 seconds
# ecoli-0-1-4-7_vs_2-3-5-6
# Testing AUC: 0.717741935483871
# This took 0.2189 seconds
# ecoli-0-1-4-7_vs_5-6
# Testing AUC: 0.6903225806451614
# This took 0.2078 seconds
# ecoli-0-1_vs_2-3-5
# Testing AUC: 0.7818181818181819
# This took 0.1383 seconds
# ecoli-0-1_vs_5
# Testing AUC: 0.7102272727272727
# This took 0.1318 seconds
# ecoli-0-2-3-4_vs_5
# Testing AUC: 0.8378378378378378
# This took 0.1173 seconds
# ecoli-0-2-6-7_vs_3-5
# Testing AUC: 0.845
# This took 0.1168 seconds
# ecoli-0-3-4-6_vs_5
# Testing AUC: 0.8108108108108109
# This took 0.1188 seconds
# ecoli-0-3-4-7_vs_5-6
# Testing AUC: 0.7148936170212766
# This took 0.1380 seconds
# ecoli-0-3-4_vs_5
# Testing AUC: 0.7361111111111112
# This took 0.1191 seconds
# ecoli-0-4-6_vs_5
# Testing AUC: 0.777027027027027
# This took 0.1091 seconds
# ecoli-0-6-7_vs_3-5
# Testing AUC: 0.975
# This took 0.1182 seconds
# ecoli-0-6-7_vs_5
# Testing AUC: 0.83125
# This took 0.1304 seconds
# ecoli-0_vs_1
# Testing AUC: 0.7494252873563219
# This took 0.1461 seconds
# ecoli1
# Testing AUC: 0.6033653846153846
# This took 0.2054 seconds
# ecoli2
# Testing AUC: 0.569377990430622
# This took 0.1846 seconds
# ecoli3
# Testing AUC: 0.5269320843091335
# This took 0.1902 seconds
# ecoli4
# Testing AUC: 0.80078125
# This took 0.2184 seconds
# flare-F
# Testing AUC: 0.8205962059620596
# This took 2.0681 seconds
# glass-0-1-2-3_vs_4-5-6
# Testing AUC: 0.75
# This took 0.1900 seconds
# glass-0-1-4-6_vs_2
# Testing AUC: 0.6418918918918919
# This took 0.1932 seconds
# glass-0-1-5_vs_2
# Testing AUC: 0.5403225806451613
# This took 0.1417 seconds
# glass-0-1-6_vs_2
# Testing AUC: 0.5285714285714286
# This took 0.1602 seconds
# glass-0-1-6_vs_5
# Testing AUC: 0.8285714285714285
# This took 0.1452 seconds
# glass-0-4_vs_5
# Testing AUC: 0.7058823529411764
# This took 0.1297 seconds
# glass-0-6_vs_5
# Testing AUC: 0.75
# This took 0.1224 seconds
# glass0
# Testing AUC: 0.7561576354679803
# This took 0.2397 seconds
# glass1
# Testing AUC: 0.5625
# This took 0.2255 seconds
# glass2
# Testing AUC: 0.5128205128205128
# This took 0.1971 seconds
# glass4
# Testing AUC: 0.8416666666666667
# This took 0.1885 seconds
# glass5
# Testing AUC: 0.9634146341463414
# This took 0.1699 seconds
# glass6
# Testing AUC: 0.7162162162162162
# This took 0.1832 seconds
# habermanImb
# Testing AUC: 0.6601307189542485
# This took 0.1691 seconds
# iris0
# Testing AUC: 0.765
# This took 0.1133 seconds
# kr-vs-k-one_vs_fifteen
# Testing AUC: 0.8393475750577367
# This took 7.8658 seconds
# kr-vs-k-three_vs_eleven
# Testing AUC: 0.8298245614035088
# This took 11.5964 seconds
# kr-vs-k-zero-one_vs_draw
# Testing AUC: 0.7854591836734695
# This took 10.7730 seconds
# kr-vs-k-zero_vs_eight
# Testing AUC: 0.5981934731934733
# This took 3.0547 seconds
# kr-vs-k-zero_vs_fifteen
# Testing AUC: 0.7582755966127791
# This took 6.1352 seconds
# led7digit-0-2-4-5-6-7-8-9_vs_1
# Testing AUC: 0.7091049382716048
# This took 0.2546 seconds
# lymphography-normal-fibrosis
# Testing AUC: 1.0
# This took 0.3376 seconds
# new-thyroid1
# Testing AUC: 0.7817460317460317
# This took 0.1168 seconds
# new-thyroid2
# Testing AUC: 0.9285714285714286
# This took 0.1175 seconds
# page-blocks-1-3_vs_4
# Testing AUC: 0.6573033707865168
# This took 0.4596 seconds
# page-blocks0
# Testing AUC: 0.6636935038511844
# This took 29.3701 seconds
# pimaImb
# Testing AUC: 0.72
# This took 0.7837 seconds
# poker-8-9_vs_5
# Testing AUC: 0.7185365853658536
# This took 4.8717 seconds
# poker-8-9_vs_6
# Testing AUC: 0.6575342465753424
# This took 3.2241 seconds
# poker-8_vs_6
# Testing AUC: 0.8125
# This took 2.6479 seconds
# poker-9_vs_7
# Testing AUC: 0.9787234042553192
# This took 0.1900 seconds
# segment0
# Testing AUC: 0.7729951025405571
# This took 6.4251 seconds
# shuttle-2_vs_5
# Testing AUC: 0.985474006116208
# This took 11.5750 seconds
# shuttle-6_vs_2-3
# Testing AUC: 0.9772727272727273
# This took 0.1571 seconds
# shuttle-c0-vs-c4
# Testing AUC: 0.714546783625731
# This took 3.9667 seconds
# shuttle-c2-vs-c4
# Testing AUC: 1.0
# This took 0.1098 seconds
# vehicle0
# Testing AUC: 0.5465384615384615
# This took 1.0674 seconds
# vehicle1
# Testing AUC: 0.5945165945165944
# This took 1.1723 seconds
# vehicle2
# Testing AUC: 0.7047258297258298
# This took 1.0560 seconds
# vehicle3
# Testing AUC: 0.5991576634316059
# This took 1.1001 seconds
# vowel0
# Testing AUC: 0.6391975308641975
# This took 1.3081 seconds
# winequality-red-3_vs_5
# Testing AUC: 0.8576642335766423
# This took 0.7293 seconds
# winequality-red-4
# Testing AUC: 0.5863489261547514
# This took 2.9538 seconds
# winequality-red-8_vs_6
# Testing AUC: 0.755859375
# This took 0.6237 seconds
# winequality-red-8_vs_6-7
# Testing AUC: 0.6601796407185629
# This took 0.9175 seconds
# winequality-white-3-9_vs_5
# Testing AUC: 0.8041095890410959
# This took 2.7941 seconds
# winequality-white-3_vs_7
# Testing AUC: 0.9801136363636364
# This took 1.0984 seconds
# winequality-white-9_vs_4
# Testing AUC: 0.6060606060606061
# This took 0.1305 seconds
# wisconsinImb
# Testing AUC: 0.9707397003745318
# This took 0.5951 seconds
# yeast-0-2-5-6_vs_3-7-8-9
# Testing AUC: 0.6303867403314918
# This took 1.2747 seconds
# yeast-0-2-5-7-9_vs_3-6-8
# Testing AUC: 0.7060773480662983
# This took 1.2890 seconds
# yeast-0-3-5-9_vs_7-8
# Testing AUC: 0.5847826086956521
# This took 0.4069 seconds
# yeast-0-5-6-7-9_vs_4
# Testing AUC: 0.522488038277512
# This took 0.4279 seconds
# yeast-1-2-8-9_vs_7
# Testing AUC: 0.5932971014492754
# This took 1.1886 seconds
# yeast-1-4-5-8_vs_7
# Testing AUC: 0.6741854636591479
# This took 0.6536 seconds
# yeast-1_vs_7
# Testing AUC: 0.6027131782945736
# This took 0.3222 seconds
# yeast-2_vs_4
# Testing AUC: 0.8606719367588933
# This took 0.4263 seconds
# yeast-2_vs_8
# Testing AUC: 0.6317204301075269
# This took 0.4062 seconds
# yeast1
# Testing AUC: 0.5292075388515376
# This took 2.5513 seconds
# yeast3
# Testing AUC: 0.5361570247933884
# This took 2.6627 seconds
# yeast4
# Testing AUC: 0.6843610934520026
# This took 3.0106 seconds
# yeast5
# Testing AUC: 0.6535493827160495
# This took 3.4996 seconds
# yeast6
# Testing AUC: 0.5911330049261083
# This took 3.5427 seconds
# zoo-3
# Testing AUC: 0.6
# This took 0.1866 seconds
